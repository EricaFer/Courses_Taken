# %%
import pandas as pd

# %%
#2 main dataypes

series = pd.Series(['BMW','Toyota','Honda'])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %% [markdown]
# #### series = 1-dimensional
#
# OBS: Series com S maiúculo

# %%
colours = pd.Series(['Red', 'Blue','White'])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
#DataFrame = 2-dimensional

car_data = pd.DataFrame({'Car Make': series, 'Colour':colours})
car_data
# Out:
#   Car Make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
#Import Data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Obs:
# axis = 0 - row
# axis = 1 - column

# %%
# Exporting a DataFrame
car_sales.to_csv('exported-car-sales.csv', index = False)
#Isso serve para tirar o Unnamed do Index
# .to_excel (exporta no formato de excel, duh)

# %%
exported_car_sales = pd.read_csv('exported-car-sales.csv')
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Obs: Importing CSV files from URL'S
#
# I could use
#
# heart_disease = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv')
#
# ### Ps: It has to be the raw file'

# %% [markdown]
# ## Describe data

# %%
#Attribute 
#has no () - just shows info
car_sales.dtypes

#Functions
#has () - performs steps
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#gives statistical info
car_sales.describe() #only shows info about int64
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %% [markdown]
# #### count: shows how many rows has the info
# #### mean : média
# #### std  : standart deviation'''

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000,1500,11250])
car_prices.mean()
# Out:
# 5250.0

# %%
car_prices.sum()
# Out:
# 15750

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Selecting and Viewing Data

# %%
car_sales.head() #shows the top 5
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail() #shows the bottow
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(['cat','dog','bird','panda','snake'],index = [0,3,9,8,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3] #refers to position
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
# .iloc refers to position (true index)
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales.Make, car_sales.Doors) #compares
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#Groupby
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales['Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
#shows the histogram
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales.Price = car_sales.Price.str.replace('[\$\,\.]','').astype(int)

# %%
car_sales.Price
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
car_sales.Price = car_sales.Price.mul(1000)
car_sales.Price
# Out:
# 0     40000.0
# 1     50000.0
# 2     70000.0
# 3    220000.0
# 4     35000.0
# 5     45000.0
# 6     75000.0
# 7     70000.0
# 8     62500.0
# 9     97000.0
# Name: Price, dtype: float64

# %%
car_sales.Price.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %%
car_sales.Make.str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales.Make = car_sales.Make.str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  toyota  White         150043      4   40000.0
# 1   honda    Red          87899      4   50000.0
# 2  toyota   Blue          32549      3   70000.0
# 3     bmw  Black          11179      5  220000.0
# 4  nissan  White         213095      4   35000.0
# 5  toyota  Green          99213      4   45000.0
# 6   honda   Blue          45698      4   75000.0
# 7   honda   Blue          54738      4   70000.0
# 8  toyota  White          60000      4   62500.0
# 9  nissan  White          31600      4   97000.0

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.Odometer.fillna(car_sales_missing.Odometer.mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing.Odometer.fillna(car_sales_missing.Odometer.mean(), inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv('car-sales-missing-dropped.csv')

# %%
#Column form series
seats_column = pd.Series([5, 5, 5, 5, 5])

#New Column called seats
car_sales['Seats'] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats
# 0  toyota  White         150043      4   40000.0    5.0
# 1   honda    Red          87899      4   50000.0    5.0
# 2  toyota   Blue          32549      3   70000.0    5.0
# 3     bmw  Black          11179      5  220000.0    5.0
# 4  nissan  White         213095      4   35000.0    5.0
# 5  toyota  Green          99213      4   45000.0    NaN
# 6   honda   Blue          45698      4   75000.0    NaN
# 7   honda   Blue          54738      4   70000.0    NaN
# 8  toyota  White          60000      4   62500.0    NaN
# 9  nissan  White          31600      4   97000.0    NaN

# %%
car_sales['Seats'].fillna(5,inplace = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats
# 0  toyota  White         150043      4   40000.0    5.0
# 1   honda    Red          87899      4   50000.0    5.0
# 2  toyota   Blue          32549      3   70000.0    5.0
# 3     bmw  Black          11179      5  220000.0    5.0
# 4  nissan  White         213095      4   35000.0    5.0
# 5  toyota  Green          99213      4   45000.0    5.0
# 6   honda   Blue          45698      4   75000.0    5.0
# 7   honda   Blue          54738      4   70000.0    5.0
# 8  toyota  White          60000      4   62500.0    5.0
# 9  nissan  White          31600      4   97000.0    5.0

# %%
#Column from list

fuel_economy = [7.5,9.2,5.0,9.6,8.7,4.7,7.6,8.7,3.0,4.5]
car_sales['Fuel per 100KM'] = fuel_economy
car_sales

#OBS

#A serie n precisa ser do mesmo tamanho, ele enche com null
#a lista precisa ser do mesmo tamanho
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   40000.0    5.0             7.5
# 1   honda    Red          87899      4   50000.0    5.0             9.2
# 2  toyota   Blue          32549      3   70000.0    5.0             5.0
# 3     bmw  Black          11179      5  220000.0    5.0             9.6
# 4  nissan  White         213095      4   35000.0    5.0             8.7
# 5  toyota  Green          99213      4   45000.0    5.0             4.7
# 6   honda   Blue          45698      4   75000.0    5.0             7.6
# 7   honda   Blue          54738      4   70000.0    5.0             8.7
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 9  nissan  White          31600      4   97000.0    5.0             4.5

# %%
car_sales['Total Fuel Use (L)'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   40000.0    5.0             7.5
# 1   honda    Red          87899      4   50000.0    5.0             9.2
# 2  toyota   Blue          32549      3   70000.0    5.0             5.0
# 3     bmw  Black          11179      5  220000.0    5.0             9.6
# 4  nissan  White         213095      4   35000.0    5.0             8.7
# 5  toyota  Green          99213      4   45000.0    5.0             4.7
# 6   honda   Blue          45698      4   75000.0    5.0             7.6
# 7   honda   Blue          54738      4   70000.0    5.0             8.7
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 9  nissan  White          31600      4   97000.0    5.0             4.5
#
#    Total Fuel Use (L)
# 0           11253.225
# 1            8086.708
# 2            1627.450
# 3            1073.184
# 4           18539.265
# 5            4663.011
# ...

# %%
#Create a Column from a single value
car_sales['Number of wheels'] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   40000.0    5.0             7.5
# 1   honda    Red          87899      4   50000.0    5.0             9.2
# 2  toyota   Blue          32549      3   70000.0    5.0             5.0
# 3     bmw  Black          11179      5  220000.0    5.0             9.6
# 4  nissan  White         213095      4   35000.0    5.0             8.7
# 5  toyota  Green          99213      4   45000.0    5.0             4.7
# 6   honda   Blue          45698      4   75000.0    5.0             7.6
# 7   honda   Blue          54738      4   70000.0    5.0             8.7
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 9  nissan  White          31600      4   97000.0    5.0             4.5
#
#    Total Fuel Use (L)  Number of wheels
# 0           11253.225                 4
# 1            8086.708                 4
# 2            1627.450                 4
# ...

# %%
car_sales['Passed road safety'] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   40000.0    5.0             7.5
# 1   honda    Red          87899      4   50000.0    5.0             9.2
# 2  toyota   Blue          32549      3   70000.0    5.0             5.0
# 3     bmw  Black          11179      5  220000.0    5.0             9.6
# 4  nissan  White         213095      4   35000.0    5.0             8.7
# 5  toyota  Green          99213      4   45000.0    5.0             4.7
# 6   honda   Blue          45698      4   75000.0    5.0             7.6
# 7   honda   Blue          54738      4   70000.0    5.0             8.7
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 9  nissan  White          31600      4   97000.0    5.0             4.5
#
#    Total Fuel Use (L)  Number of wheels  Passed road safety
# 0           11253.225                 4                True
# ...

# %%
car_sales.drop('Total Fuel Use (L)',axis = 1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   40000.0    5.0             7.5
# 1   honda    Red          87899      4   50000.0    5.0             9.2
# 2  toyota   Blue          32549      3   70000.0    5.0             5.0
# 3     bmw  Black          11179      5  220000.0    5.0             9.6
# 4  nissan  White         213095      4   35000.0    5.0             8.7
# 5  toyota  Green          99213      4   45000.0    5.0             4.7
# 6   honda   Blue          45698      4   75000.0    5.0             7.6
# 7   honda   Blue          54738      4   70000.0    5.0             8.7
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 9  nissan  White          31600      4   97000.0    5.0             4.5
#
#    Total Fuel Use (L)  Number of wheels  Passed road safety
# 0           11253.225                 4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac = 1) #fraction that will be randomized 1 = 100%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 3     bmw  Black          11179      5  220000.0    5.0             9.6
# 2  toyota   Blue          32549      3   70000.0    5.0             5.0
# 4  nissan  White         213095      4   35000.0    5.0             8.7
# 6   honda   Blue          45698      4   75000.0    5.0             7.6
# 5  toyota  Green          99213      4   45000.0    5.0             4.7
# 0  toyota  White         150043      4   40000.0    5.0             7.5
# 1   honda    Red          87899      4   50000.0    5.0             9.2
# 9  nissan  White          31600      4   97000.0    5.0             4.5
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 7   honda   Blue          54738      4   70000.0    5.0             8.7
#
#    Total Fuel Use (L)  Number of wheels  Passed road safety
# 3            1073.184                 4                True
# ...

# %%
#Only select 20% of the data 
car_sales_shuffled.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 2  toyota   Blue          32549      3  70000.0    5.0             5.0
# 8  toyota  White          60000      4  62500.0    5.0             3.0
#
#    Total Fuel Use (L)  Number of wheels  Passed road safety
# 2             1627.45                 4                True
# 8             1800.00                 4                True

# %%
car_sales_shuffled.reset_index(drop = True, inplace = True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 0     bmw  Black          11179      5  220000.0    5.0             9.6
# 1  toyota   Blue          32549      3   70000.0    5.0             5.0
# 2  nissan  White         213095      4   35000.0    5.0             8.7
# 3   honda   Blue          45698      4   75000.0    5.0             7.6
# 4  toyota  Green          99213      4   45000.0    5.0             4.7
# 5  toyota  White         150043      4   40000.0    5.0             7.5
# 6   honda    Red          87899      4   50000.0    5.0             9.2
# 7  nissan  White          31600      4   97000.0    5.0             4.5
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 9   honda   Blue          54738      4   70000.0    5.0             8.7
#
#    Total Fuel Use (L)  Number of wheels  Passed road safety
# 0            1073.184                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   40000.0    5.0             7.5
# 1   honda    Red          87899      4   50000.0    5.0             9.2
# 2  toyota   Blue          32549      3   70000.0    5.0             5.0
# 3     bmw  Black          11179      5  220000.0    5.0             9.6
# 4  nissan  White         213095      4   35000.0    5.0             8.7
# 5  toyota  Green          99213      4   45000.0    5.0             4.7
# 6   honda   Blue          45698      4   75000.0    5.0             7.6
# 7   honda   Blue          54738      4   70000.0    5.0             8.7
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 9  nissan  White          31600      4   97000.0    5.0             4.5
#
#    Total Fuel Use (L)  Number of wheels  Passed road safety
# 0           11253.225                 4                True
# ...

# %%
car_sales['Odometer (Miles)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   40000.0    5.0             7.5
# 1   honda    Red          87899      4   50000.0    5.0             9.2
# 2  toyota   Blue          32549      3   70000.0    5.0             5.0
# 3     bmw  Black          11179      5  220000.0    5.0             9.6
# 4  nissan  White         213095      4   35000.0    5.0             8.7
# 5  toyota  Green          99213      4   45000.0    5.0             4.7
# 6   honda   Blue          45698      4   75000.0    5.0             7.6
# 7   honda   Blue          54738      4   70000.0    5.0             8.7
# 8  toyota  White          60000      4   62500.0    5.0             3.0
# 9  nissan  White          31600      4   97000.0    5.0             4.5
#
#    Total Fuel Use (L)  Number of wheels  Passed road safety  Odometer (Miles)
# 0           11253.225                 4                True         93776.875
# ...

# %% [markdown]
# #### Dealing with multiple sheets with pandas
#
# `data_file = pd.read_excel('path_to_file.xls', sheet_name="sheet_name")`
